# %% [markdown]
# '''Concrete Compressive Strength
# Use the Concrete Compressive Strength dataset.
# This dataset contains quantitative data on the composition of concrete mixtures and their
# measured compressive strength.
# a. Apply Linear Regression using a suitable library function to predict the compressive
# strength of concrete based on ingredient proportions (cement, water, coarse and fine aggregate,
# etc.).
# b. Evaluate model performance using Mean Squared Error (MSE), Mean Absolute Error
# (MAE), and R² Score.
# c. Visualize the regression model by comparing the predicted and actual compressive strength
# values.'''

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Concrete_Data (1).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Cement (component 1)(kg in a m^3 mixture)              1030 non-null   float64
#  1   Blast Furnace Slag (component 2)(kg in a m^3 mixture)  1030 non-null   float64
#  2   Fly Ash (component 3)(kg in a m^3 mixture)             1030 non-null   float64
#  3   Water  (component 4)(kg in a m^3 mixture)              1030 non-null   float64
#  4   Superplasticizer (component 5)(kg in a m^3 mixture)    1030 non-null   float64
#  5   Coarse Aggregate  (component 6)(kg in a m^3 mixture)   1030 non-null   float64
#  6   Fine Aggregate (component 7)(kg in a m^3 mixture)      1030 non-null   float64
#  7   Age (day)                                              1030 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  281.167864
# std                                   104.506364
# min                                   102.000000
# 25%                                   192.375000
# 50%                                   272.900000
# 75%                                   350.000000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                           73.895825
# std                                            86.279342
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           142.950000
# ...

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.isnull()
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 1025                                      False
# 1026                                      False
# 1027                                      False
# 1028                                      False
# 1029                                      False
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...

# %%
df.isnull().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                0
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0
# Fly Ash (component 3)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)                0
# Superplasticizer (component 5)(kg in a m^3 mixture)      0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     0
# Fine Aggregate (component 7)(kg in a m^3 mixture)        0
# Age (day)                                                0
# Concrete compressive strength(MPa, megapascals)          0
# dtype: int64

# %%
print(list(df.columns))
# Out:
# ['Cement (component 1)(kg in a m^3 mixture)', 'Blast Furnace Slag (component 2)(kg in a m^3 mixture)', 'Fly Ash (component 3)(kg in a m^3 mixture)', 'Water  (component 4)(kg in a m^3 mixture)', 'Superplasticizer (component 5)(kg in a m^3 mixture)', 'Coarse Aggregate  (component 6)(kg in a m^3 mixture)', 'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)', 'Concrete compressive strength(MPa, megapascals) ']

# %%
# Separate independent variables (X) and target variable (y)
x = df.drop('Concrete compressive strength(MPa, megapascals) ', axis=1)
y = df['Concrete compressive strength(MPa, megapascals) ']

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into 80% training and 20% testing
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=42)

# %%
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (824, 8)
# x_test shape: (206, 8)
# y_train shape: (824,)
# y_test shape: (206,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
model_lr = LinearRegression()
model_dt = DecisionTreeRegressor(random_state=1)

# %%
model_lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
y_pred_lr = model_lr.predict(x_test)
y_pred_dt = model_dt.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred_lr)
mae = mean_absolute_error(y_test, y_pred_lr)
r2 = r2_score(y_test, y_pred_lr)

# %%
print("\nModel Performance:")
print(f"Mean Squared Error (MSE): ",mse)
print(f"Mean Absolute Error (MAE):" ,mae)
print(f"R² Score: {r2:.2f}")
# Out:
# Model Performance:
# Mean Squared Error (MSE):  95.9709400911068
# Mean Absolute Error (MAE): 7.745559243921434
# R² Score: 0.63

# %%
import matplotlib.pyplot as plt

# Create scatter plot
#
plt.scatter(y_test, y_pred_lr,label="Actual")

# Add red dashed line for perfect prediction
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)],'r--',label="Predicted",lw=2) #'r--') means red dashed line (r = red, -- = dashed)

# Add labels and title
plt.xlabel("Actual Sound Pressure (dB)")
plt.ylabel("Predicted Sound Pressure (dB)")
plt.title("Actual vs Predicted Sound Pressure")

# Show plot
plt.legend()
plt.show()
